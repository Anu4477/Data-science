# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu4477/Data-science/blob/main/14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import package pandas
import pandas as pd
# <ld >method Series
#example1
l=[10,20,30]
df=pd.Series(data=l)
print(df)

#example2
d={"name":"ram","age":20,"roll-no":123}
df=pd.Series(data=d,index=["name","age","roll-no"])
print(df)

#suggestion
#help(pd,Series)
#pd.Series?
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# name       ram
# age         20
# roll-no    123
# dtype: object

# %%
import pandas as pd

d={
    "name":["Kunal","dheeraj","anjali","praveen","yash","danish"],
    "roll-no":[12,13,14,15,16,17]
}
df = pd.DataFrame(data=d)
print(df)
# Out:
#       name  roll-no
# 0    Kunal       12
# 1  dheeraj       13
# 2   anjali       14
# 3  praveen       15
# 4     yash       16
# 5   danish       17

# %%
#csv file
import pandas as pd
df=pd.read_csv("data.csv")
print(df)
