# %%
print("hello")
# Out:
# hello

# %%
num1=10
num2=20
print(num1 and num2)

num1="hello"
num2=""
print(num1 or num2)
print(num2 or num1)

num1=[]
print(not num1)

num1={}
print(not num1)
# Out:
# 20
# hello
# hello
# True
# True

# %%
server_down=True
backup_active=False
if server_down and not backup_active:
  print("critical warning")

# %%
#bitwise operator
a=5
b=2
print(a&b)
print(a<<b)
print(a>>b)


print(22//2)
print(22>>1)
# Out:
# 0
# 20
# 1
# 11
# 11

# %%
#identity  operator
name = 10
name1=10
print(name==name1)
print (name is name1)
print(id(name))
print(id(name1))

#ex1  (-5 to 256) same memory p rehta h  both vriable point at same variable
num1=10
num2=10.0
print(num1==num2)
print(num1 is  num2)
print(id(num1))
print(id(num2))



num1=[1,2,3]
num2=[1,2,3]
num3=num1
print(num1==num2)
print(num1 is  num2)
print(id(num1))
print(id(num2))
print(id(num3))
# Out:
# True
# True
# 11645640
# 11645640
# True
# False
# 11645640
# 136461955978864
# True
# False
# 136461953635136
# 136461953633792
# 136461953635136

# %% [markdown]
# conditional statements

# %%
#if
num1=10
num2=20
if num1 <num2 :
  print(num2)

#if else
num1=int(input("enter the number: "))
if num1:
  print("number:-",num1)
else:
  print("Zero",num1)


  #if elif else
  age=int(input("Enter the number:"))
  if age ==18:
    print("Your age is",age)
  elif age >18:
    print("u are above then",age)
  else:
    print("you are less then",age)
# Out:
# 20
# enter the number: 10
# number:- 10

# %%
 #if elif else
age= int(input("Enter the number:"))
 if age ==18:
   print("Your age is",age)
 elif age >18:
   print("u are above then 18<",age)
 else:
   print("you are less then 18 >",age)
# Out:
# Enter the number:45
# u are above then 18< 45

# %%
marks= int(input("Enter the marks: "))
if marks >= 60 & marks <= 75:
    print("C grade")
elif marks > 75 & marks <= 90:
    print("B grade")
elif marks >90:
    print("A grade")
else:
    print("Fail")
# Out:
# Enter the marks: 59
# C grade

# %% [markdown]
# loops

# %%
#for loop
for i in range(5):
 print("i= ",i)

#for
 for i in range(1,11):
  print("number=",i)
# Out:
# i=  0
# number= 1
# number= 2
# number= 3
# number= 4
# number= 5
# number= 6
# number= 7
# number= 8
# number= 9
# number= 10
# i=  1
# number= 1
# number= 2
# number= 3
# number= 4
# number= 5
# number= 6
# number= 7
# number= 8
# number= 9
# number= 10
# i=  2
# number= 1
# number= 2
# number= 3
# number= 4
# number= 5
# number= 6
# number= 7
# number= 8
# number= 9
# number= 10
# i=  3
# number= 1
# number= 2
# number= 3
# number= 4
# number= 5
# number= 6
# number= 7
# number= 8
# number= 9
# number= 10
# i=  4
# number= 1
# number= 2
# number= 3
# number= 4
# number= 5
# number= 6
# number= 7
# number= 8
# number= 9
# number= 10

# %%
#list
l=[11,12,13,14]
#print(len(l))
#for i in range(4):
 # print(l[i])
for i in range (len(l)):
  print(l[i])

  for i in l:
   print(i)
# Out:
# 11
# 11
# 12
# 13
# 14
# 12
# 11
# 12
# 13
# 14
# 13
# 11
# 12
# 13
# 14
# 14
# 11
# 12
# 13
# 14

# %%
#while loop
#num1 =int(input("enter the no:"))
#i=0
#while i < num1:
  #print(i)
  #i+= 1


  #list
l=[10,11,12,13,14,15]
i=0


while i < len(l):
    print(l[i])
    i+=1
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
#example
d = {"name":"hello","age":20,"phone":"0000000"}
print(d.keys())

for i in range (len(d.keys())):
  print(i)
# Out:
# dict_keys(['name', 'age', 'phone'])
# 0
# 1
# 2

# %%
l=[10,[11,12,13,14]]

for i in range(2,len(l[1])):
  print(l[1][i])

for i in l[1]:
  print(i)
# Out:
# 13
# 14
# 11
# 12
# 13
# 14

# %%
#break
for i in range(5):
  if i == 2:
    break
  print(i)

# continue
#i = 0
#while True:
#  print(i)
 # if i == 5:
   # break
  #else:
   # i += 1
    #continue


 #pass
i = 0
while True:
  print(i)
  if i == 4:
    pass
  if i == 5:
    break
  else:
    i += 1
    continue
# Out:
# 0
# 1
# 0
# 1
# 2
# 3
# 4
# 5
