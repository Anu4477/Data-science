# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu4477/Data-science/blob/main/27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# polynomical regression
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# data
df = pd.DataFrame({
    "Experience":[1,2,3,4,5]
})
x = df
y = [10, 20, 50, 90, 150]

# poly feature
poly = PolynomialFeatures(degree=2)  # x**2
x_poly = poly.fit_transform(x)
print(x_poly)

# model
model = LinearRegression()
model.fit(x_poly,y)

# prediction
input_data  = int(input('Enter the experience: '))
new_data = pd.DataFrame({
    "Experience":[input_data]
})

# convert new data to poly
u_new_data = poly.fit_transform(new_data)
predicted_data = model.predict(u_new_data)
print(predicted_data[0])

#graph
plt.plot(x_poly,y)
#plt.plot(x,model.predict(x_poly))
plt.show()
# Out:
# [[ 1.  1.  1.]
#  [ 1.  2.  4.]
#  [ 1.  3.  9.]
#  [ 1.  4. 16.]
#  [ 1.  5. 25.]]
# Enter the experience: 4
# 91.14285714285717

# %%
#Linear regression ->under fitting
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.DataFrame({
    "level":[1,2,3,4,5]
})
x=df
y=[10,20,50,90,150]

#model
model=LinearRegression()
model.fit(x,y)

#prediction
input_data=int(input("Enter the level: "))
new_data=pd.DataFrame({
    "level":[input_data]
})
predicted_data=model.predict(new_data)
print(predicted_data[0])

#
# Out:
# Enter the level: 6
# 169.00000000000003

# %%
#poly regression ->over fitting
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
df=pd.DataFrame({
    "level":[1,2,3,4,5]
})
x=df
y=[10,20,50,90,150]

# poly feature
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

#model
model=LinearRegression()
model.fit(x_poly,y)

#prediction
input_data=int(input("Enter the level: "))
new_data=pd.DataFrame({
    "level":[input_data]
})

# input data to poly
u_new_data=poly.fit_transform(new_data)

#predict
predicted_data=model.predict(u_new_data)
print(predicted_data[0])
