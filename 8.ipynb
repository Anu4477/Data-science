# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu4477/Data-science/blob/main/8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Address:
  def __init__(self,city,state):
   self.city = "jaipur"
   self.state = "Rajasthan"

  def show(self):
    print("the city is:")


    a = Address("jaipur","rajasthan")
    #print(a.city)

# %%
class Address:
    def __init__(self, city, state):
        self.city = city
        self.state = state

    def location(self):
        return f"My location is {self.city}, in {self.state}"


class User(Address):
    def __init__(self, name, age, city, state):
        super().__init__(city, state)
        self.name = name
        self.age = age

    def userName(self):
        print(f"My name is {self.name}")

    def userDetails(self):
        print(f"My name is {self.name} and my location is {self.city} in {self.state}")


u = User("Anushka", 20, "Kukas", "Rajasthan")

u.userName()
u.userDetails()
print(u.location())
# Out:
# My name is Anushka
# My name is Anushka and my location is Kukas in Rajasthan
# My location is Kukas, in Rajasthan

# %%
class Address:
  def __init__(self,city,state):
    self.city = city
    self.state = state

  def location(self):
    return f"my location is {self.city} in {self.state}"

class User(Address):
  def __init__(self,name,age,city,state):
    self.name = name
    self.age = age
    self.city = city
    self.state = state

  def userName(self):
    print(f"my name is {self.name}")

  def userDetails(self):
    print(f"my name is {self.name} and my location is {self.city} in {self.state}")

u = User("Anushka",20,"kukas","rajasthan")
u.userDetails()
u.location()

# a = Address("kukas","rajasthan")
# Out:
# my name is Anushka and my location is kukas in rajasthan
# 'my location is kukas in rajasthan'

# %%
class Address:
  def __init__(self,city,state):
    self.__city = city# attribute
    self.state = state

  def location(self):
    print(f"my location is {self.__city} in {self.state}")


  def get_city(self):
    return self.__city
a = Address("varanasi","UP")
a.location()
#print(a.__city)
print(a.state)
# Out:
# my location is varanasi in UP
# UP

# %% [markdown]
# **POLYMORPHISM**

# %%
class Address:
  def __init__(self,city,state):
    self.__city = city# attribute
    self.state = state

  def location(self):
    print(f"my  address location is {self.__city} in {self.state}")

class HomeTown:
    def __init__(self,city,state):
      self.__city = city# attribute
      self.state = state

    def location(self):
      print(f"my HomeTown location is {self.__city} in {self.state}")

a = Address("vadodara","Gujarat")
a.location()

b = HomeTown("surat","Gujarat")
b.location()
# Out:
# my  address location is vadodara in Gujarat
# my HomeTown location is surat in Gujarat

# %% [markdown]
# CLASS VARIABLE

# %%
class Address:
  total = 10
  def __init__(self,city,state):
    self.__city = city# attribute
    self.state = state
    Address.total += 1

  def location(self):
    print("location")

a = Address("vadodara","Gujarat")


b = Address("surat","Gujarat")

a.total
# Out:
# 12

# %% [markdown]
# **OVERLOADING** **AND** **OVERRIDING**

# %%
def address(city,state):
  print(f"my address is {city} in {state}")

def address(city,state,country):
  print(f"my address is {city} at {state} in {country}")

address("jaipur","rajasthan","india")
# Out:
# my address is jaipur at rajasthan in india

# %%
# Overriding
class Address:
  def __init__(self,city,state):
    self.__city = city# attribute
    self.state = state

  def location(self):
    print("address")

class User(Address):
  def __init__(self,name,age,city,state):
    super().__init__(city,state)
    self.name = name
    self.age = age

 # def location(self):
   # print("user location")

u = User("Anushka",20,"kukas","rajasthan")
u.location()
# Out:
# address

# %% [markdown]
# **Tuples**

# %%
#immutable
t = (10,20,30)
print(t[0])
print(t[-1])

#example
marks = [98,90,80,95]
#marks[3]=50
#print(type(marks))
#print(marks)

#tuple
t=tuple(marks)
print(type(t))
print(t)

m = list(t)
print(type(m))
print(m)
# Out:
# 10
# 30
# <class 'tuple'>
# (98, 90, 80, 95)
# <class 'list'>
# [98, 90, 80, 95]

# %%
data = {1:"Apple", 1.0: "Banaras"}
print(data[1])
# Out:
# Banaras
